# %% [markdown]
# Importar bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Leer resultados

# %%
df = pd.read_csv("../resultados.csv")
df.head()
# Out:
#    cantThreadsCarga  tiempoCarga
# 0                 1     0.002129
# 1                 2     0.000738
# 2                 3     0.000471
# 3                 4     0.000596
# 4                 5     0.000682

# %% [markdown]
# Grafico de tiempo transcurrido en función de la cantidad de threads utilizados

# %%
df["tiempo"] = df["tiempo"].apply(lambda x: x*1000)
plot = sns.lineplot(x="cantThreads", y="tiempo", data=df);

plot.legend(["cant_threads vs tiempo"]);
plot.set(ylabel="Tiempo");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b952c213b32e> in <module>
# ----> 1 plot = sns.lineplot(x="cantThreads", y="tiempo", data=df);
#       2
#       3 plot.legend(["cant_threads vs tiempo"]);
#       4 plot.set(ylabel="Tiempo");
#
# ~/.local/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1124         dashes=dashes, markers=markers, style_order=style_order,
#    1125         units=units, estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# -> 1126         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1127     )
#    1128
#
# ~/.local/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     693
#     694         plot_data = self.establish_variables(
# --> 695             x, y, hue, size, style, units, data
#     696         )
#     697
#
# ~/.local/lib/python3.7/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     135                 if isinstance(var, str):
#     136                     err = "Could not interpret input '{}'".format(var)
# --> 137                     raise ValueError(err)
#     138
#     139             # Extract variable names
#
# ValueError: Could not interpret input 'cantThreads'

# %%
df["tiempoCarga"] = df["tiempoCarga"].apply(lambda x: x*1000)
plot = sns.lineplot(x="cantThreadsCarga", y="tiempoCarga", data=df);

plot.legend(["cant_threads vs tiempo"]);
plot.set(ylabel="Tiempo");
